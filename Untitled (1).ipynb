# %%
import pandas as pd
data= pd.read_excel("suruuu.xlsx")
print(data)
# Out:
#     Product id  bill no   selesman name  Unnamed: 3 product name  Unnamed: 5  \
# 0         1001     1234  suravi rakshit         NaN         cake         NaN
# 1         1002     1235  sayani rakshit         NaN          oil         NaN
# 2         1003     1236       onik pal          NaN    chocalate         NaN
# 3         1004     1237     debasis pal         NaN       chipes         NaN
# 4         1005     1238    joy chouduri         NaN       fruiti         NaN
# 5         1006     1239        yami roy         NaN  mango juice         NaN
# 6         1007     1240      surbhi roy         NaN  apple juice         NaN
# 7         1008     1341       polas bej         NaN         bear         NaN
# 8         1009     1342       plumi roy         NaN         wine         NaN
# 9         1010     1343        tiya sen         NaN          ata         NaN
# 10        1011     1344        piya sen         NaN         rice         NaN
# ...

# %%
import pandas as pd
data=pd.read_excel("suruuu.xlsx")
print(data)
# Out:
#     Product id  bill no   selesman name  Unnamed: 3 product name  Unnamed: 5  \
# 0         1001     1234  suravi rakshit         NaN         cake         NaN
# 1         1002     1235  sayani rakshit         NaN          oil         NaN
# 2         1003     1236       onik pal          NaN    chocalate         NaN
# 3         1004     1237     debasis pal         NaN       chipes         NaN
# 4         1005     1238    joy chouduri         NaN       fruiti         NaN
# 5         1006     1239        yami roy         NaN  mango juice         NaN
# 6         1007     1240      surbhi roy         NaN  apple juice         NaN
# 7         1008     1341       polas bej         NaN         bear         NaN
# 8         1009     1342       plumi roy         NaN         wine         NaN
# 9         1010     1343        tiya sen         NaN          ata         NaN
# 10        1011     1344        piya sen         NaN         rice         NaN
# ...

# %%
print(data.isnull())
# Out:
#     Product id  bill no  selesman name  Unnamed: 3  product name  Unnamed: 5  \
# 0        False    False          False        True         False        True
# 1        False    False          False        True         False        True
# 2        False    False          False        True         False        True
# 3        False    False          False        True         False        True
# 4        False    False          False        True         False        True
# 5        False    False          False        True         False        True
# 6        False    False          False        True         False        True
# 7        False    False          False        True         False        True
# 8        False    False          False        True         False        True
# 9        False    False          False        True         False        True
# 10       False    False          False        True         False        True
# ...

# %%
data.isnull().sum()
# Out:
# Product id        0
# bill no           0
# selesman name     0
# Unnamed: 3       49
# product name      0
# Unnamed: 5       49
# zone              0
# seles             0
# dtype: int64

# %%
import pandas as pd
data=pd.read_excel("moni3.xlsx")
print(data.head(10))
# Out:
#   stop _data stop_time  country_name driver_name driver gender  \
# 0 2024-01-02   12.00am           NaN          SR             F
# 1 2024-01-03    1.00am           NaN          PR             M
# 2 2024-01-04    2.00am           NaN          MN             F
# 3 2024-01-05    3.00am           NaN          ER             M
# 4 2024-01-06    4.00am           NaN          SU             F
# 5 2024-01-07    5.00am           NaN          DU             M
# 6 2024-01-08    6.00am           NaN          DK             M
# 7 2024-01-09    7.00am           NaN          FK             F
# 8 2024-01-10    8.00am           NaN          GK             F
# 9 2024-01-11    9.00am           NaN          HN             M
#
#    driver_age_raw  Unnamed: 6  driver age car color violation_raw violacation  \
# 0          1950.0         NaN        74.0       red      speeding    speeding
# 1          1941.0         NaN        83.0      blue      speeding    speeding
# ...

# %%
data.isnull()
# Out:
#     stop _data  stop_time  country_name  driver_name  driver gender  \
# 0        False      False          True        False          False
# 1        False      False          True        False          False
# 2        False      False          True        False          False
# 3        False      False          True        False          False
# 4        False      False          True        False          False
# 5        False      False          True        False          False
# 6        False      False          True        False          False
# 7        False      False          True        False          False
# 8        False      False          True        False          False
# 9        False      False          True        False          False
# 10       False      False          True        False          False
# 11       False      False          True        False          False
# 12       False      False          True        False          False
# ...

# %%
data.notnull()
# Out:
#     stop _data  stop_time  country_name  driver_name  driver gender  \
# 0         True       True         False         True           True
# 1         True       True         False         True           True
# 2         True       True         False         True           True
# 3         True       True         False         True           True
# 4         True       True         False         True           True
# 5         True       True         False         True           True
# 6         True       True         False         True           True
# 7         True       True         False         True           True
# 8         True       True         False         True           True
# 9         True       True         False         True           True
# 10        True       True         False         True           True
# 11        True       True         False         True           True
# 12        True       True         False         True           True
# ...

# %%
import pandas as pd
data=pd.read_excel("moni3.xlsx")
print(data)
# Out:
#    stop _data stop_time  country_name driver_name driver gender  \
# 0  2024-01-02   12.00am           NaN          SR             F
# 1  2024-01-03    1.00am           NaN          PR             M
# 2  2024-01-04    2.00am           NaN          MN             F
# 3  2024-01-05    3.00am           NaN          ER             M
# 4  2024-01-06    4.00am           NaN          SU             F
# 5  2024-01-07    5.00am           NaN          DU             M
# 6  2024-01-08    6.00am           NaN          DK             M
# 7  2024-01-09    7.00am           NaN          FK             F
# 8  2024-01-10    8.00am           NaN          GK             F
# 9  2024-01-11    9.00am           NaN          HN             M
# 10 2024-01-12   10.00am           NaN          JK             M
# 11 2024-01-13   11.00am           NaN          LK             F
# 12 2024-01-14   12.00pm           NaN          GH             M
# 13 2024-01-15    1.00pm           NaN          BN             F
# ...

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   stop _data         59 non-null     datetime64[ns]
#  1   stop_time          59 non-null     object
#  2   country_name       0 non-null      float64
#  3   driver_name        59 non-null     object
#  4   driver gender      59 non-null     object
#  5   driver_age_raw     58 non-null     float64
#  6   Unnamed: 6         0 non-null      float64
#  7   driver age         58 non-null     float64
#  8   car color          58 non-null     object
#  9   violation_raw      57 non-null     object
#  10  violacation        53 non-null     object
#  11  search_conducted   58 non-null     float64
# dtypes: datetime64[ns](1), float64(5), object(6)
# memory usage: 5.7+ KB
# None

# %%
print(data.describe())
# Out:
#                 stop _data  country_name  driver_age_raw  Unnamed: 6  \
# count                   59           0.0       58.000000         0.0
# mean   2024-01-31 00:00:00           NaN     1968.672414         NaN
# min    2024-01-02 00:00:00           NaN     1941.000000         NaN
# 25%    2024-01-16 12:00:00           NaN     1954.250000         NaN
# 50%    2024-01-31 00:00:00           NaN     1968.500000         NaN
# 75%    2024-02-14 12:00:00           NaN     1982.750000         NaN
# max    2024-02-29 00:00:00           NaN     1997.000000         NaN
# std                    NaN           NaN       16.640036         NaN
#
#        driver age  search_conducted
# count   58.000000               58.0
# mean    55.327586                0.0
# min     27.000000                0.0
# 25%     41.250000                0.0
# 50%     55.500000                0.0
# 75%     69.750000                0.0
# max     83.000000                0.0
# std     16.640036                0.0

# %%
print(data.duplicated())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# 53    False
# 54    False
# 55    False
# 56    False
# 57    False
# 58    False
# dtype: bool

# %%
print(data.drop_duplicates("driver gender"))
# Out:
#    stop _data stop_time  country_name driver_name driver gender  \
# 0  2024-01-02   12.00am           NaN          SR             F
# 1  2024-01-03    1.00am           NaN          PR             M
# 56 2024-02-27    7.00am           NaN          MD           NAN
#
#     driver_age_raw  Unnamed: 6  driver age car color violation_raw  \
# 0           1950.0         NaN        74.0       red      speeding
# 1           1941.0         NaN        83.0      blue      speeding
# 56          1996.0         NaN        28.0       red      speeding
#
#    violacation  search_conducted
# 0     speeding                0.0
# 1     speeding                0.0
# 56    speeding                0.0

# %%
import pandas as pd
data=pd.read_excel("moni3.xlsx")
print(data)
(data.guorpby('driver gender'))
# Out:
#    stop _data stop_time  country_name driver_name driver gender  \
# 0  2024-01-02   12.00am           NaN          SR             F
# 1  2024-01-03    1.00am           NaN          PR             M
# 2  2024-01-04    2.00am           NaN          MN             F
# 3  2024-01-05    3.00am           NaN          ER             M
# 4  2024-01-06    4.00am           NaN          SU             F
# 5  2024-01-07    5.00am           NaN          DU             M
# 6  2024-01-08    6.00am           NaN          DK             M
# 7  2024-01-09    7.00am           NaN          FK             F
# 8  2024-01-10    8.00am           NaN          GK             F
# 9  2024-01-11    9.00am           NaN          HN             M
# 10 2024-01-12   10.00am           NaN          JK             M
# 11 2024-01-13   11.00am           NaN          LK             F
# 12 2024-01-14   12.00pm           NaN          GH             M
# 13 2024-01-15    1.00pm           NaN          BN             F
# ...

# %%
import  pandas as pd
import matplotlib.pyplot as plt
data=pd.read_excel("moni3.xlsx")
df=pd.DataFrame(data)
print(data)
# Out:
#    stop _data stop_time  country_name driver_name driver gender  \
# 0  2024-01-02   12.00am           NaN          SR             F
# 1  2024-01-03    1.00am           NaN          PR             M
# 2  2024-01-04    2.00am           NaN          MN             F
# 3  2024-01-05    3.00am           NaN          ER             M
# 4  2024-01-06    4.00am           NaN          SU             F
# 5  2024-01-07    5.00am           NaN          DU             M
# 6  2024-01-08    6.00am           NaN          DK             M
# 7  2024-01-09    7.00am           NaN          FK             F
# 8  2024-01-10    8.00am           NaN          GK             F
# 9  2024-01-11    9.00am           NaN          HN             M
# 10 2024-01-12   10.00am           NaN          JK             M
# 11 2024-01-13   11.00am           NaN          LK             F
# 12 2024-01-14   12.00pm           NaN          GH             M
# 13 2024-01-15    1.00pm           NaN          BN             F
# ...
